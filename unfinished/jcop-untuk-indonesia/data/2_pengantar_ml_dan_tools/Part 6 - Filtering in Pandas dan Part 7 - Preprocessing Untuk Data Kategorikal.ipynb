# %%
import numpy as np
import pandas as pd

from luwiji.pandas import illustration

# %% [markdown]
# # Import data

# %%
df = pd.read_csv("pandas_data/cereal_imp.csv", index_col="name")
df
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %%
df.rating > 70
# Out:
# name
# 100% Bran                    False
# 100% Natural Bran            False
# All-Bran                     False
# All-Bran with Extra Fiber     True
# Almond Delight               False
#                              ...
# Triples                      False
# Trix                         False
# Wheat Chex                   False
# Wheaties                     False
# Wheaties Honey Gold          False
# Name: rating, Length: 77, dtype: bool

# %%
df[df.rating > 70] # cari semua dalam data yang rating diatas 70
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Shredded Wheat 'n'Bran      N    C        90        3    0       0    4.0
# Shredded Wheat spoon size   N    C        90        3    0       0    3.0
#
#                            carbo  sugars  potass vitamins  shelf  weight  \
# name
# All-Bran with Extra Fiber    8.0     0.0   330.0   FDA_25      3     1.0
# Shredded Wheat 'n'Bran      19.0     0.0   140.0    FDA_0      1     1.0
# Shredded Wheat spoon size   20.0     0.0   120.0    FDA_0      1     1.0
#
#                            cups     rating
# name
# All-Bran with Extra Fiber  0.50  93.704912
# Shredded Wheat 'n'Bran     0.67  74.472949
# Shredded Wheat spoon size  0.67  72.801787

# %%
df[~(df.shelf == 1)].head() # ambil semua kecuali shelfnya bernilai 1
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars      potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0  280.000000   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0  135.000000    FDA_0      3     1.0
# All-Bran                     7.0     5.0  320.000000   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0  330.000000   FDA_25      3     1.0
# Almond Delight              14.0     8.0   98.666667   FDA_25      3     1.0
#
#                            cups     rating
# ...

# %%
df[(df.rating > 50) & (df.fat == 0)]
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Bran Flakes                 P    C        90        3    0     210    5.0
# Cream of Wheat (Quick)      N    H       100        3    0      80    1.0
# Frosted Mini-Wheats         K    C       100        3    0       0    3.0
# Grape-Nuts                  P    C       110        3    0     170    3.0
# Nutri-grain Wheat           K    C        90        3    0     170    3.0
# Puffed Rice                 Q    C        50        1    0       0    0.0
# Puffed Wheat                Q    C        50        2    0       0    1.0
# Raisin Squares              K    C        90        2    0       0    2.0
# Shredded Wheat              N    C        80        2    0       0    3.0
# Shredded Wheat 'n'Bran      N    C        90        3    0       0    4.0
# Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# ...

# %%
df[(df.mfr.isin(["K","N"])) | (df.rating > 70)]
# Out:
#                             mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                     N    C        70        4    1     130   10.0
# All-Bran                      K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber     K    C        50        4    0     140   14.0
# Apple Jacks                   K    C       110        2    0     125    1.0
# Corn Flakes                   K    C       100        2    0     290    1.0
# Corn Pops                     K    C       110        1    0      90    1.0
# Cracklin' Oat Bran            K    C       110        3    3     140    4.0
# Cream of Wheat (Quick)        N    H       100        3    0      80    1.0
# Crispix                       K    C       110        2    0     220    1.0
# Froot Loops                   K    C       110        2    1     125    1.0
# Frosted Flakes                K    C       110        1    0     200    1.0
# ...

# %%
# direkomendasikan tambah .copy()
# karena jika tidak, object yang dibuat saling terhubung dengan object intinya
df_my_preferences = df[(df.rating > 60) & (df.mfr.isin(['K','N']))].copy() 
df_my_preferences
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Cream of Wheat (Quick)      N    H       100        3    0      80    1.0
# Shredded Wheat              N    C        80        2    0       0    3.0
# Shredded Wheat 'n'Bran      N    C        90        3    0       0    4.0
# Shredded Wheat spoon size   N    C        90        3    0       0    3.0
#
#                            carbo  sugars      potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0  280.000000   FDA_25      3    1.00
# All-Bran with Extra Fiber    8.0     0.0  330.000000   FDA_25      3    1.00
# Cream of Wheat (Quick)      21.0     0.0   98.666667    FDA_0      2    1.00
# Shredded Wheat              16.0     0.0   95.000000    FDA_0      1    0.83
# ...

# %%
df_my_preferences.sort_values('rating') # diurutkan berdasarkan rating
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# Cream of Wheat (Quick)      N    H       100        3    0      80    1.0
# Shredded Wheat              N    C        80        2    0       0    3.0
# 100% Bran                   N    C        70        4    1     130   10.0
# Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# Shredded Wheat 'n'Bran      N    C        90        3    0       0    4.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#                            carbo  sugars      potass vitamins  shelf  weight  \
# name
# Cream of Wheat (Quick)      21.0     0.0   98.666667    FDA_0      2    1.00
# Shredded Wheat              16.0     0.0   95.000000    FDA_0      1    0.83
# 100% Bran                    5.0     6.0  280.000000   FDA_25      3    1.00
# Shredded Wheat spoon size   20.0     0.0  120.000000    FDA_0      1    1.00
# ...

# %%
df_my_preferences.sort_values('rating', ascending=False, inplace=True) 
df_my_preferences
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Shredded Wheat 'n'Bran      N    C        90        3    0       0    4.0
# Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 100% Bran                   N    C        70        4    1     130   10.0
# Shredded Wheat              N    C        80        2    0       0    3.0
# Cream of Wheat (Quick)      N    H       100        3    0      80    1.0
#
#                            carbo  sugars      potass vitamins  shelf  weight  \
# name
# All-Bran with Extra Fiber    8.0     0.0  330.000000   FDA_25      3    1.00
# Shredded Wheat 'n'Bran      19.0     0.0  140.000000    FDA_0      1    1.00
# Shredded Wheat spoon size   20.0     0.0  120.000000    FDA_0      1    1.00
# 100% Bran                    5.0     6.0  280.000000   FDA_25      3    1.00
# ...

# %% [markdown]
# # Group by

# %%
df.groupby('shelf') # group by, misahin berdasarkan kategori

# %%
# groupby harus ada aggregate, karena aggregate adalah bentuk kumpulannya mau diapakan dan ditampilkan menjadi 1
df.groupby('shelf').mean()
# Out:
#          calories   protein   fat      sodium     fiber      carbo    sugars  \
# shelf
# 1      102.500000  2.650000  0.60  176.250000  1.685000  16.590132  5.201316
# 2      109.523810  1.904762  1.00  145.714286  0.904762  13.619048  9.619048
# 3      107.777778  2.861111  1.25  158.611111  3.138889  14.500000  6.527778
#
#            potass    weight      cups     rating
# shelf
# 1       75.500000  0.991500  0.897000  46.145439
# 2       62.555556  1.015714  0.911429  34.972827
# 3      132.601852  1.058889  0.726111  45.220032

# %%
df.groupby(['mfr', 'shelf']).mean()
# Out:
#              calories   protein       fat      sodium      fiber      carbo  \
# mfr shelf
# A   2      100.000000  4.000000  1.000000    0.000000   0.000000  16.000000
# G   1      106.666667  3.000000  1.333333  223.333333   1.833333  14.500000
#     2      111.428571  1.285714  1.285714  204.285714   0.000000  14.000000
#     3      114.444444  2.666667  1.444444  182.222222   1.888889  15.444444
# K   1      107.500000  2.750000  0.000000  252.500000   0.750000  18.250000
#     2      111.428571  2.142857  0.571429  115.714286   1.714286  12.428571
#     3      107.500000  2.916667  0.833333  183.333333   4.000000  15.666667
# N   1       86.666667  2.666667  0.000000    0.000000   3.333333  18.333333
#     2       95.000000  2.500000  0.000000   47.500000   2.000000  18.000000
#     3       70.000000  4.000000  1.000000  130.000000  10.000000   5.000000
# P   1      105.000000  1.500000  0.000000  112.500000   0.000000  12.500000
# ...

# %%
# dibacanya: jika ada korelasi pada mfr dan shelf tertentu, tunjukkan jumlahnya ada berapa
df.groupby(['mfr', 'shelf']).size()
# Out:
# mfr  shelf
# A    2         1
# G    1         6
#      2         7
#      3         9
# K    1         4
#      2         7
#      3        12
# N    1         3
#      2         2
#      3         1
# P    1         2
#      2         1
#      3         6
# Q    1         1
#      2         3
#      3         4
# R    1         4
#      3         4
# dtype: int64

# %%
# dibacanya: pada mfr dan shelf tertentu, rata2 ratingnya berapa. Jika NaN maka tidak ada 
df.pivot_table(index='mfr', columns='shelf', values="rating", aggfunc="mean")
# Out:
# shelf          1          2          3
# mfr
# A            NaN  54.850917        NaN
# G      39.872079  26.069929  37.440751
# K      42.747695  37.131878  48.497559
# N      71.836874  61.948905  68.402973
# P      31.997429  28.025765  47.221846
# Q      50.828392  28.414072  51.814327
# R      45.587913        NaN  37.498082

# %% [markdown]
# # New Column and Drop Column

# %%
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars      potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0  280.000000   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0  135.000000    FDA_0      3     1.0
# All-Bran                     7.0     5.0  320.000000   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0  330.000000   FDA_25      3     1.0
# Almond Delight              14.0     8.0   98.666667   FDA_25      3     1.0
#
#                            cups     rating
# ...

# %%
# tambah kolom baru dan isi semua dengan nilai 23
df["kolom_baru"] = 23
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars      potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0  280.000000   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0  135.000000    FDA_0      3     1.0
# All-Bran                     7.0     5.0  320.000000   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0  330.000000   FDA_25      3     1.0
# Almond Delight              14.0     8.0   98.666667   FDA_25      3     1.0
#
# ...

# %%
data_baru = np.random.rand(len(df))
data_baru
# Out:
# array([0.75350306, 0.79402431, 0.6270408 , 0.09796644, 0.51101409,
#        0.20934845, 0.7550606 , 0.72726786, 0.09237169, 0.20103477,
#        0.32006315, 0.13598211, 0.18116266, 0.01417159, 0.52898803,
#        0.62155298, 0.32869225, 0.27346255, 0.40599449, 0.06543513,
#        0.91315917, 0.37430496, 0.28512168, 0.50121705, 0.98819249,
#        0.04756574, 0.50997477, 0.79967756, 0.48196657, 0.1829725 ,
#        0.35069503, 0.50835097, 0.11318745, 0.62093777, 0.49615981,
#        0.00873958, 0.88844638, 0.41062367, 0.80907046, 0.46212896,
#        0.78319394, 0.0686097 , 0.103375  , 0.43097326, 0.77872478,
#        0.896147  , 0.13863543, 0.18537726, 0.81885892, 0.0230134 ,
#        0.01232455, 0.25708798, 0.14020964, 0.15874855, 0.05437026,
#        0.64430425, 0.58476775, 0.28956817, 0.77859694, 0.58814289,
#        0.5216972 , 0.73711796, 0.9001527 , 0.16117729, 0.76258918,
#        0.36472747, 0.16141226, 0.14037297, 0.86258094, 0.34251081,
# ...

# %%
# tambah kolom baru dan isi semua dengan nilai random sepanjang baris df
df["kolom_baru"] = data_baru
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars      potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0  280.000000   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0  135.000000    FDA_0      3     1.0
# All-Bran                     7.0     5.0  320.000000   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0  330.000000   FDA_25      3     1.0
# Almond Delight              14.0     8.0   98.666667   FDA_25      3     1.0
#
# ...

# %%
# hapus kolom baru
df.drop(columns=['kolom_baru'], inplace=True)
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars      potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0  280.000000   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0  135.000000    FDA_0      3     1.0
# All-Bran                     7.0     5.0  320.000000   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0  330.000000   FDA_25      3     1.0
# Almond Delight              14.0     8.0   98.666667   FDA_25      3     1.0
#
#                            cups     rating
# ...

# %% [markdown]
# # Map, Apply, and Transform

# %%
# memetakan value tertentu menjadi value tertentu
df['shelf_baru'] = df.shelf.map({
    1: "bawah",
    2: "tengah",
    3: "atas"
})
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars      potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0  280.000000   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0  135.000000    FDA_0      3     1.0
# All-Bran                     7.0     5.0  320.000000   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0  330.000000   FDA_25      3     1.0
# Almond Delight              14.0     8.0   98.666667   FDA_25      3     1.0
#
# ...

# %%
# apply -> melakukan sesuatu pada seluruh kolom itu
df['fat_mg'] = df.fat.apply(lambda x: x * 1000)
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars      potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0  280.000000   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0  135.000000    FDA_0      3     1.0
# All-Bran                     7.0     5.0  320.000000   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0  330.000000   FDA_25      3     1.0
# Almond Delight              14.0     8.0   98.666667   FDA_25      3     1.0
#
# ...

# %%
# Scalling
# penskalaan dari skala lama ke 0 sampai 1
# misal nilai min adalah 3 dan maksimal 13 diskalakan baru menjadi 0 sampai 1
# rumus:
# x_new = (x-x_min) / (x_max-x_min)

# %%
# beda transform dan apply:
# transform -> x yang dimasukkan adalah semua x yang ada di df, jadi ada x.min nya dan x.maxnya dari semua x di df
# apply -> x yang dimasukkan adalah x pada saat itu aja, jadi x.min nya dan x.maxnya yang x itu sendiri

df['scaled_rating'] = df.rating.transform( lambda x: (x-x.min())/(x.max()-x.min()) )
df
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %%
df.drop(columns=["shelf_baru", "fat_mg", "scaled_rating"], inplace=True)

# %%
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars      potass vitamins  shelf  weight  \
# name
# 100% Bran                    5.0     6.0  280.000000   FDA_25      3     1.0
# 100% Natural Bran            8.0     8.0  135.000000    FDA_0      3     1.0
# All-Bran                     7.0     5.0  320.000000   FDA_25      3     1.0
# All-Bran with Extra Fiber    8.0     0.0  330.000000   FDA_25      3     1.0
# Almond Delight              14.0     8.0   98.666667   FDA_25      3     1.0
#
#                            cups     rating
# ...

# %% [markdown]
# ---
# ***

# %% [markdown]
# # Konsep Encoding pada Data Kategorikal
# - Untuk data yang bersifat kategorikal(misal: mfr yang berisi manufacturer2 biskuit)
# - machine learning tidak bisa menerima yang tipenya object atau bahkan string. Oleh karena itu data kategorikal perlu di encode menjadi angka (numerikal)
# - Ada 2 cara:
#      - label encoding (ordinal encoding)
#      - dummy variable encoding (one hot encoding)
# - label encoding:
#      -tiap kategori direpresentasikan dalam angka
#      - misal:
#          - bawah -> 0
#          - tengah -> 1
#          - atas -> 2
# - one hot encoding (lebih banyak dipakai karena lebih fleksibel):
#     | shelfnya | isBawah | isTengah | isAtas |
#     |----------|---------|----------|--------|
#     | bawah    | 1       | 0        | 0      |
#     | tengah   | 0       | 1        | 0      |
#     | atas     | 0       | 0        | 1      |

# %% [markdown]
# # One Hot Encoding / Dummy Variable

# %%
df = pd.get_dummies(df, columns=['vitamins'], prefix_sep="__")
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars      potass  shelf  weight  cups  \
# name
# 100% Bran                    5.0     6.0  280.000000      3     1.0  0.33
# 100% Natural Bran            8.0     8.0  135.000000      3     1.0  1.00
# All-Bran                     7.0     5.0  320.000000      3     1.0  0.33
# All-Bran with Extra Fiber    8.0     0.0  330.000000      3     1.0  0.50
# Almond Delight              14.0     8.0   98.666667      3     1.0  0.75
#
# ...

# %% [markdown]
# # Binning (Kotak2in)
# - Kebalikan dari sebelumnya -> mengubah data numerikal menjadi kategorikal
# - misal umur
# |Usia    |Kategori   |
# |--------|-----------|
# | 0-5    | balita    |
# | 5-10   | anak-anak |
# | 10-18  | remaja    |
# | 18-40  | dewasa    |
# | 40-120 | lansia    |

# %%
# Mengkategorikan rating menjadi grade A, B, dan C
# binsnya ada 4 sedangkan labelnya ada 3 karena bins itu interval
# jadi dari 0-40 -> grade C, 41-70 -> grade B, 71-maks -> grade A
df['grade'] = pd.cut(df.rating, bins=[0, 40, 70, df.rating.max()], labels=["C", "B", "A"])
df.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars      potass  shelf  weight  cups  \
# name
# 100% Bran                    5.0     6.0  280.000000      3     1.0  0.33
# 100% Natural Bran            8.0     8.0  135.000000      3     1.0  1.00
# All-Bran                     7.0     5.0  320.000000      3     1.0  0.33
# All-Bran with Extra Fiber    8.0     0.0  330.000000      3     1.0  0.50
# Almond Delight              14.0     8.0   98.666667      3     1.0  0.75
#
# ...
